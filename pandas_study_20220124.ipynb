# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Country': ['대한민국', '일본', '캐나다', '미국', '프랑스', '독일', '영국'],
    'City': ['서울', '도쿄', '토론토', '뉴욕', '파리', '베를린', '런던'],
    'Population': [9543, 37340, 6255, 18823, 11079, 3567, 9426],
}

# %%
df = pd.DataFrame(data, index= ['대한민국', '일본', '캐나다', '미국', '프랑스', '독일', '영국'])
df
# Out:
#      Country City  Population
# 대한민국    대한민국   서울        9543
# 일본        일본   도쿄       37340
# 캐나다      캐나다  토론토        6255
# 미국        미국   뉴욕       18823
# 프랑스      프랑스   파리       11079
# 독일        독일  베를린        3567
# 영국        영국   런던        9426

# %%
df_index_with_country = df.set_index("Country")
df_index_with_country
# Out:
#         City  Population
# Country
# 대한민국      서울        9543
# 일본        도쿄       37340
# 캐나다      토론토        6255
# 미국        뉴욕       18823
# 프랑스       파리       11079
# 독일       베를린        3567
# 영국        런던        9426

# %%
df.loc[0]
# Out:
# Country       대한민국
# City            서울
# Population    9543
# Name: 0, dtype: object

# %%
data = {
    'col1' : [1,2,3,4],
    'col2' : [5,6,7,8],
    'col3' : [9, 10, 11, 12],
}

df3 = pd.DataFrame(data, index = ['A', 'B', 'C', 'D'])

df3
# Out:
#    col1  col2  col3
# A     1     5     9
# B     2     6    10
# C     3     7    11
# D     4     8    12

# %%
s1 = pd.Series([1, 2, 3, 4], index=['A', 'B', 'C', 'D'])
s2 = pd.Series([5, 6, 7, 8], index=['A', 'B', 'C', 'D'])
s3 = pd.Series([9, 10, 11, 12], index=['A', 'B', 'C', 'D'])

s1_t = [1,2,3,4]

data = {
        'col1' : s1_t,
        'col2' : s2,
        'col3' : s3,
}

df4 = pd.DataFrame(data, index=['A', 'B', 'C', 'D'])

df4
# Out:
#    col1  col2  col3
# A     1     5     9
# B     2     6    10
# C     3     7    11
# D     4     8    12

# %%
df4 + 10
# Out:
#    col1  col2  col3
# A    11    15    19
# B    12    16    20
# C    13    17    21
# D    14    18    22

# %%
df4 + df4
# Out:
#    col1  col2  col3
# A     2    10    18
# B     4    12    20
# C     6    14    22
# D     8    16    24

# %%
a=df_index_with_country['Population']
b=df_index_with_country.loc['대한민국']['Population']
a/b
# Out:
# Country
# 대한민국    1.000000
# 일본      3.912816
# 캐나다     0.655454
# 미국      1.972441
# 프랑스     1.160956
# 독일      0.373782
# 영국      0.987740
# Name: Population, dtype: float64

# %%
df_index_with_country
# Out:
#         City  Population
# Country
# 대한민국      서울        9543
# 일본        도쿄       37340
# 캐나다      토론토        6255
# 미국        뉴욕       18823
# 프랑스       파리       11079
# 독일       베를린        3567
# 영국        런던        9426

# %%
df_index_with_country.insert(2, 'result', df_index_with_country['Population']/df_index_with_country.loc['대한민국']['Population'])

# %%
df_index_with_country.round(decimals=2)
# Out:
#         City  Population  result
# Country
# 대한민국      서울        9543    1.00
# 일본        도쿄       37340    3.91
# 캐나다      토론토        6255    0.66
# 미국        뉴욕       18823    1.97
# 프랑스       파리       11079    1.16
# 독일       베를린        3567    0.37
# 영국        런던        9426    0.99

# %%
json_data = df.to_json()

# %%
json_data
# Out:
# '{"Country":{"\\ub300\\ud55c\\ubbfc\\uad6d":"\\ub300\\ud55c\\ubbfc\\uad6d","\\uc77c\\ubcf8":"\\uc77c\\ubcf8","\\uce90\\ub098\\ub2e4":"\\uce90\\ub098\\ub2e4","\\ubbf8\\uad6d":"\\ubbf8\\uad6d","\\ud504\\ub791\\uc2a4":"\\ud504\\ub791\\uc2a4","\\ub3c5\\uc77c":"\\ub3c5\\uc77c","\\uc601\\uad6d":"\\uc601\\uad6d"},"City":{"\\ub300\\ud55c\\ubbfc\\uad6d":"\\uc11c\\uc6b8","\\uc77c\\ubcf8":"\\ub3c4\\ucfc4","\\uce90\\ub098\\ub2e4":"\\ud1a0\\ub860\\ud1a0","\\ubbf8\\uad6d":"\\ub274\\uc695","\\ud504\\ub791\\uc2a4":"\\ud30c\\ub9ac","\\ub3c5\\uc77c":"\\ubca0\\ub97c\\ub9b0","\\uc601\\uad6d":"\\ub7f0\\ub358"},"Population":{"\\ub300\\ud55c\\ubbfc\\uad6d":9543,"\\uc77c\\ubcf8":37340,"\\uce90\\ub098\\ub2e4":6255,"\\ubbf8\\uad6d":18823,"\\ud504\\ub791\\uc2a4":11079,"\\ub3c5\\uc77c":3567,"\\uc601\\uad6d":9426}}'

# %%
pd.read_json(json_data)
# Out:
#      Country City  Population
# 대한민국    대한민국   서울        9543
# 일본        일본   도쿄       37340
# 캐나다      캐나다  토론토        6255
# 미국        미국   뉴욕       18823
# 프랑스      프랑스   파리       11079
# 독일        독일  베를린        3567
# 영국        영국   런던        9426

# %%
df_iris = pd.read_csv('C:\\Users\\배진우\\Documents\\multiCampus_TA\\python_data\\iris_sample.csv')

# %%
df_iris
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# ...

# %%
pd.read_csv('C:\\Users\\배진우\\Documents\\multiCampus_TA\\python_data\\iris_sample.tsv', sep='\t')
# Out:
#     x   y
# 0   5  90
# 1  25  30
# 2  45  50
# 3  65  55
# 4  85  25

# %%
df_iris.to_csv('iris_sample2.csv')

# %%
#Json 파일 형식 간략 설명

#wget을 활용하여 iris_sample data 가져오기(코랩에서만 작동)
# !wget -O 'iris_sample.csv' https://raw.githubusercontent.com/duc-ke/edu_jupyter_pandas/master/dataset/iris_sample.csv

#iris_sample.csv 로 저장된 파일 Pandas로 import하기 (경로가 다르다면 수정 필요)
df_iris = pd.read_csv('iris_sample.csv')
print(df_iris)

#iris_sample.csv 로 저장된 파일 Pandas로 export하기 (경로가 다르다면 수정 필요)
df_iris.to_csv('iris_sample2.csv')

## 위의 csv의 경우에는 seperate가 ' ' space로 구분되어있어서 sep을 따로 지정해주지않아도 됩니다.

#tsv '\t' 탭으로 구분된 경우
# !wget -O 'iris_sample.tsv' https://raw.githubusercontent.com/duc-ke/edu_jupyter_pandas/master/dataset/iris_sample.csv
df_iris2 = pd.read_csv('iris_sample.tsv')
print(df_iris2)

#sep 인자를 지정해주기
df_iris2 = pd.read_csv('iris_sample.tsv', sep='\t')
print(df_iris2)
# Out:
# 'wget'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8908/1052011948.py in <module>
#       5
#       6 #iris_sample.csv 로 저장된 파일 Pandas로 import하기 (경로가 다르다면 수정 필요)
# ----> 7 df_iris = pd.read_csv('iris_sample.csv')
#       8 print(df_iris)
#       9
#
# C:\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# !pip install xlsxwriter

# %%
# !pip install mysql-connector-python

# %%
import sqlalchemy

# %%
user = 'anonymous'
host = 'ensembldb.ensembl.org'
port = '3337'
database = 'ailuropoda_melanoleuca_core_79_1'

url = f"mysql+mysqlconnector://{user}@{host}:{port}/{database}"
    
connection = sqlalchemy.create_engine(url)

# %%
connection
# Out:
# Engine(mysql+mysqlconnector://anonymous@ensembldb.ensembl.org:3337/ailuropoda_melanoleuca_core_79_1)

# %%
pd.read_sql('select * from analysis limit 10', connection)
# Out:
#    analysis_id             created     logic_name             db  \
# 0           10 2010-01-27 18:23:33        genscan  HumanIso.smat
# 1          151 2010-06-17 12:10:04  other_protein           None
# 2           38 2010-01-27 18:23:34        eponine        eponine
# 3          147 2010-06-17 12:10:04            trf           None
# 4          148 2010-06-17 12:10:04       trnascan           trna
# 5           43 2010-01-27 18:23:34        unigene         uniuni
# 6           45 2010-01-27 18:23:34           dust           None
# 7           49 2010-01-27 18:23:34            cpg           None
# 8           51 2010-01-27 18:23:34        vertrna   embl_vertrna
# 9           46 2010-01-27 18:23:34        firstef           None
#
#       db_version                               db_file       program  \
# 0           None                         HumanIso.smat          None
# 1  uniprot_15_14                                  None          None
# ...

# %%
df = df.reset_index()
df
# Out:
#    level_0 index Country City  Population
# 0        0  대한민국    대한민국   서울        9543
# 1        1    일본      일본   도쿄       37340
# 2        2   캐나다     캐나다  토론토        6255
# 3        3    미국      미국   뉴욕       18823
# 4        4   프랑스     프랑스   파리       11079
# 5        5    독일      독일  베를린        3567
# 6        6    영국      영국   런던        9426

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'Country', 'City', 'Population'], dtype='object')

# %%
df.rename(columns={'level_0' : 'c1', 'index' : 'c2'}, inplace=True)

# %%
df
# Out:
#    c1    c2 Country City  Population
# 0   0  대한민국    대한민국   서울        9543
# 1   1    일본      일본   도쿄       37340
# 2   2   캐나다     캐나다  토론토        6255
# 3   3    미국      미국   뉴욕       18823
# 4   4   프랑스     프랑스   파리       11079
# 5   5    독일      독일  베를린        3567
# 6   6    영국      영국   런던        9426

# %%
df.iloc[0:2, 0:2]
# Out:
#    c1    c2
# 0   0  대한민국
# 1   1    일본

# %%
df.loc[0:2]
# Out:
#    c1    c2 Country City  Population
# 0   0  대한민국    대한민국   서울        9543
# 1   1    일본      일본   도쿄       37340
# 2   2   캐나다     캐나다  토론토        6255

# %%
df[0:2]
# Out:
#    c1    c2 Country City  Population
# 0   0  대한민국    대한민국   서울        9543
# 1   1    일본      일본   도쿄       37340

# %%
del df['c1']

# %%
del df['c2']

# %%
df
# Out:
#   Country City  Population
# 0    대한민국   서울        9543
# 1      일본   도쿄       37340
# 2     캐나다  토론토        6255
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079
# 5      독일  베를린        3567
# 6      영국   런던        9426

# %%
df.columns = ['Country', 'City', 'Population']

# %%
df
# Out:
#   Country City  Population
# 0    대한민국   서울        9543
# 1      일본   도쿄       37340
# 2     캐나다  토론토        6255
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079
# 5      독일  베를린        3567
# 6      영국   런던        9426

# %%
df.loc[df.loc[:, 'Population'] > 10000]
# Out:
#   Country City  Population
# 1      일본   도쿄       37340
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079

# %%
df.loc[df['Population'] > 10000, 'City']
# Out:
# 1    도쿄
# 3    뉴욕
# 4    파리
# Name: City, dtype: object

# %%
i = df.loc[:, 'Population'] > 10000
df[i]
# Out:
#   Country City  Population
# 1      일본   도쿄       37340
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079

# %%
df.loc[i]
# Out:
#   Country City  Population
# 1      일본   도쿄       37340
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079

# %%
df.iloc[:, 2] > 10000
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# Name: Population, dtype: bool

# %%
df[[True,False,True,False,True,False,False]]
# Out:
#   Country City  Population
# 0    대한민국   서울        9543
# 2     캐나다  토론토        6255
# 4     프랑스   파리       11079

# %%
data = {
    'country' : ['Belgium', 'France', 'Germany', 'Netherland', 'United Kingdom'],
    'population' : [11.4, 65.2, 83.7, 17.3, 67.8
                   ],
    'area' : [30510, 671308, 357050, 41526, 244820],
    'capital' : ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']
} 

countries = pd.DataFrame(data)
countries = countries.set_index('country')

countries
# Out:
#                 population    area    capital
# country
# Belgium               11.4   30510   Brussels
# France                65.2  671308      Paris
# Germany               83.7  357050     Berlin
# Netherland            17.3   41526  Amsterdam
# United Kingdom        67.8  244820     London

# %%
countries['density'] = countries.loc[:, 'population'] * 1000000/ countries.loc[:, 'area']

# %%
countries
# Out:
#                 population    area    capital     density
# country
# Belgium               11.4   30510   Brussels  373.647984
# France                65.2  671308      Paris   97.123824
# Germany               83.7  357050     Berlin  234.420949
# Netherland            17.3   41526  Amsterdam  416.606463
# United Kingdom        67.8  244820     London  276.938159

# %%
density = countries.loc[:, 'population'] * 1000000/ countries.loc[:, 'area']
density
# Out:
# country
# Belgium           373.647984
# France             97.123824
# Germany           234.420949
# Netherland        416.606463
# United Kingdom    276.938159
# dtype: float64

# %%
countries.loc[countries.loc[:,'density'] >= 300,['capital', 'population']]
# Out:
#               capital  population
# country
# Belgium      Brussels        11.4
# Netherland  Amsterdam        17.3

# %%
rank = countries.loc[:,'population'].rank(ascending =True)
rank
# Out:
# country
# Belgium           1.0
# France            3.0
# Germany           5.0
# Netherland        2.0
# United Kingdom    4.0
# Name: population, dtype: float64

# %%
test = pd.concat([density, rank], axis=1, ignore_index=True)

# %%
test
# Out:
#                          0    1
# country
# Belgium         373.647984  1.0
# France           97.123824  3.0
# Germany         234.420949  5.0
# Netherland      416.606463  2.0
# United Kingdom  276.938159  4.0

# %%
countries[countries['density'] >= 300]
# Out:
#             population   area    capital     density
# country
# Belgium           11.4  30510   Brussels  373.647984
# Netherland        17.3  41526  Amsterdam  416.606463

# %%
countries[countries['density'] >= 300][['capital','population']]
# Out:
#               capital  population
# country
# Belgium      Brussels        11.4
# Netherland  Amsterdam        17.3

# %%
countries[['capital','population']][countries['density'] >= 300]
# Out:
#               capital  population
# country
# Belgium      Brussels        11.4
# Netherland  Amsterdam        17.3

# %%
countries['density_ratio'] = countries['density']/ countries['density'].mean()

# %%
np.mean(countries.density)
# Out:
# 279.74747594394637

# %%
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.4   30510   Brussels  373.647984       1.335662
# France                65.2  671308      Paris   97.123824       0.347184
# Germany               83.7  357050     Berlin  234.420949       0.837973
# Netherland            17.3   41526  Amsterdam  416.606463       1.489223
# United Kingdom        67.8  244820     London  276.938159       0.989958

# %%
countries['density'].mean()
# Out:
# 279.74747594394637

# %%
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.4   30510   Brussels  373.647984       1.335662
# France                65.2  671308      Paris   97.123824       0.347184
# Germany               83.7  357050     Berlin  234.420949       0.837973
# Netherland            17.3   41526  Amsterdam  416.606463       1.489223
# United Kingdom        67.8  244820     London  276.938159       0.989958

# %%
countries.iloc[4,2] = 'Manchester1'

# %%
countries
# Out:
#                 population    area      capital     density  density_ratio
# country
# Belgium               11.4   30510     Brussels  373.647984       1.335662
# France                65.2  671308        Paris   97.123824       0.347184
# Germany               83.7  357050       Berlin  234.420949       0.837973
# Netherland            17.3   41526    Amsterdam  416.606463       1.489223
# United Kingdom        67.8  244820  Manchester1  276.938159       0.989958

# %%
countries.loc['United Kingdom', 'capital'] = 'Manchester2'

# %%
countries
# Out:
#                 population    area      capital     density  density_ratio
# country
# Belgium               11.4   30510     Brussels  373.647984       1.335662
# France                65.2  671308        Paris   97.123824       0.347184
# Germany               83.7  357050       Berlin  234.420949       0.837973
# Netherland            17.3   41526    Amsterdam  416.606463       1.489223
# United Kingdom        67.8  244820  Manchester2  276.938159       0.989958

# %%
countries.loc['United Kingdom', 'capital'] = 'Manchester'

# %%
countries.loc[countries.loc[:, 'density']>=100]
# Out:
#                 population    area     capital     density  density_ratio
# country
# Belgium               11.4   30510    Brussels  373.647984       1.335662
# Germany               83.7  357050      Berlin  234.420949       0.837973
# Netherland            17.3   41526   Amsterdam  416.606463       1.489223
# United Kingdom        67.8  244820  Manchester  276.938159       0.989958

# %%
countries.loc[countries.loc[:, 'density']>=100][countries.loc[:, 'density']<300]
# Out:
# C:\Users\배진우\AppData\Local\Temp/ipykernel_8908/492042048.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   countries.loc[countries.loc[:, 'density']>=100][countries.loc[:, 'density']<300]
#                 population    area     capital     density  density_ratio
# country
# Germany               83.7  357050      Berlin  234.420949       0.837973
# United Kingdom        67.8  244820  Manchester  276.938159       0.989958

# %%
countries.loc[(countries.loc[:, 'density']>=100) & (countries.loc[:, 'density']<300) ]
# Out:
#                 population    area     capital     density  density_ratio
# country
# Germany               83.7  357050      Berlin  234.420949       0.837973
# United Kingdom        67.8  244820  Manchester  276.938159       0.989958

# %%
(countries.loc[:, 'density']>=100) & (countries.loc[:, 'density']<300)
# Out:
# country
# Belgium           False
# France            False
# Germany            True
# Netherland        False
# United Kingdom     True
# Name: density, dtype: bool

# %%
countries.loc[(countries.loc[:, 'density']>=100) & (countries.loc[:, 'density']<300) ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8908/2096646229.py in <module>
# ----> 1 (100 <= countries.loc[:, 'density']<300)
#
# C:\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
countries.loc[(countries.loc[:,'capital'].str.len() >= 7), :]
# Out:
#                 population    area     capital     density  density_ratio
# country
# Belgium               11.4   30510    Brussels  373.647984       1.335662
# Netherland            17.3   41526   Amsterdam  416.606463       1.489223
# United Kingdom        67.8  244820  Manchester  276.938159       0.989958

# %%
countries.loc[:,'capital'].str.len() >= 7
# Out:
# country
# Belgium            True
# France            False
# Germany           False
# Netherland         True
# United Kingdom     True
# Name: capital, dtype: bool

# %%
countries
# Out:
#                 population    area     capital     density  density_ratio
# country
# Belgium               11.4   30510    Brussels  373.647984       1.335662
# France                65.2  671308       Paris   97.123824       0.347184
# Germany               83.7  357050      Berlin  234.420949       0.837973
# Netherland            17.3   41526   Amsterdam  416.606463       1.489223
# United Kingdom        67.8  244820  Manchester  276.938159       0.989958

# %%
countries.loc['United Kingdom', 'capital'] = 'London'

# %%
condition = countries.loc[:,'capital'].str.contains('Lo')
condition
# Out:
# country
# Belgium           False
# France            False
# Germany           False
# Netherland        False
# United Kingdom     True
# Name: capital, dtype: bool

# %%
countries.loc[condition, :]
# Out:
#                 population    area capital     density  density_ratio
# country
# United Kingdom        67.8  244820  London  276.938159       0.989958

# %%
df
# Out:
#   Country City  Population
# 0    대한민국   서울        9543
# 1      일본   도쿄       37340
# 2     캐나다  토론토        6255
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079
# 5      독일  베를린        3567
# 6      영국   런던        9426

# %%
df.drop(1)
# Out:
#   Country City  Population
# 0    대한민국   서울        9543
# 2     캐나다  토론토        6255
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079
# 5      독일  베를린        3567
# 6      영국   런던        9426

# %%
df.drop([2,3])
# Out:
#   Country City  Population
# 0    대한민국   서울        9543
# 1      일본   도쿄       37340
# 4     프랑스   파리       11079
# 5      독일  베를린        3567
# 6      영국   런던        9426

# %%
df.drop(['Country', 'City'], axis=1)
# Out:
#    Population
# 0        9543
# 1       37340
# 2        6255
# 3       18823
# 4       11079
# 5        3567
# 6        9426

# %%
df.sort_values('Population')
# Out:
#   Country City  Population
# 5      독일  베를린        3567
# 2     캐나다  토론토        6255
# 6      영국   런던        9426
# 0    대한민국   서울        9543
# 4     프랑스   파리       11079
# 3      미국   뉴욕       18823
# 1      일본   도쿄       37340

# %%
df.sort_values('Population', ascending= False)
# Out:
#   Country City  Population
# 1      일본   도쿄       37340
# 3      미국   뉴욕       18823
# 4     프랑스   파리       11079
# 0    대한민국   서울        9543
# 6      영국   런던        9426
# 2     캐나다  토론토        6255
# 5      독일  베를린        3567

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     7 non-null      object
#  1   City        7 non-null      object
#  2   Population  7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
df.describe()
# Out:
#          Population
# count      7.000000
# mean   13719.000000
# std    11442.721719
# min     3567.000000
# 25%     7840.500000
# 50%     9543.000000
# 75%    14951.000000
# max    37340.000000

# %%
df.isnull().any(axis = 1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df.isnull().any().any()
# Out:
# False

# %%
pd.read_excel('C:\\Users\\배진우\\Documents\\multiCampus_TA\\python_data\\영화정보 리스트_2022-01-25.xls' )
# Out:
#                                    영화명               영화명(영문)  제작연도 제작국가  유형  \
# 0                          장민호 드라마 최종회      Jang Minho Drama  2022   한국  장편
# 1                              서바이벌리스트       The Survivalist  2021   미국  장편
# 2                                  코만도          The Commando  2021   미국  장편
# 3                              내 친구의 봄                   NaN  2016   한국  단편
# 4                            레스큐 더 파일럿  The Shelburn Network  2019  프랑스  장편
# ...                                ...                   ...   ...  ...  ..
# 45544               퍼시잭슨과 번개도둑+의형제+울프맨     Package Screening  2010   기타  장편
# 45545       500일의 썸머+들어는 봤니? 모건 부부+의형제     Package Screening  2010   기타  장편
# 45546        500일의 썸머+들어는봤니? 모건 부부+하모니     Package Screening  2010   기타  장편
# 45547  파라노말 액티비티+주유소 습격사건2+아빠가 여자를 좋아해     Package Screening  2010   기타  장편
# 45548        500일의 썸머+용서는 없다+주유소 습격사건2     Package Screening  2010   기타  장편
#
# ...
