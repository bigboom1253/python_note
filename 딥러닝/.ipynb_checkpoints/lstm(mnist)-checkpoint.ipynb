# %%
# LSTM으로 mnist 데이터를 분류한다.
from tensorflow.keras.layers import Input, Dense, LSTM
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pickle

# 저장된 mnist 데이터를 읽어온다.
DATA_PATH = 'C:\\Users\\배진우\\Documents\\multiCampus_TA\\python_data'
with open(DATA_PATH + 'mnist.pkl', 'rb') as f:
        mnist = pickle.load(f)

# mnist['data'] 숫자의 범위를 변환한다 (표준화) : 0 ~ 255 --> 0 ~ 1.0
# target = ['1', '2',...] 문자로 돼있음. --> 숫자로 변환해야 함.
x_feat = np.array(mnist['data']).reshape(-1, 28, 28) / 255
y_target = np.array(mnist['target'].to_numpy().astype('int8')).reshape(-1,1)

# 학습 데이터와 시험 데이터를 생성한다.
x_train, x_test, y_train, y_test = train_test_split(x_feat, y_target, test_size=0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape

# 그래프 모델을 생성한다
n_hNeuron = 50
n_class = len(set(mnist['target']))

xInput = Input(batch_shape=(None, x_train.shape[1], x_train.shape[2]))
hLayer = LSTM(n_hNeuron)(xInput)
yOutput = Dense(n_class, activation='softmax')(hLayer)

model = Model(xInput, yOutput)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
model.summary()

hist = model.fit(x_train, y_train, 
                 batch_size=1024, 
                 epochs=50, 
                 validation_data = (x_test, y_test))

# error가 감소하는 모습을 관찰한다.
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.title("Loss function")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()

y_prob = model.predict(x_test)
y_pred = np.argmax(y_prob, axis=1).reshape(-1,1)
acc = (y_test == y_pred).mean()
print('정확도 ={:.4f}'.format(acc))

import pandas as pd
df = pd.DataFrame({'y_test': y_test.reshape(-1,), 'y_pred': y_pred.reshape(-1,)})
df.head(10)

# 잘못 분류한 이미지 몇개를 확인해 본다.
# 어떤 이미지를 잘 맞추지 못할까? 사람이라면 아래 이미지를 잘 맞출 수 있을까?
n_sample = 10
miss_cls = np.where(y_test != y_pred)[0]
miss_sam = np.random.choice(miss_cls, n_sample)

fig, ax = plt.subplots(1, n_sample, figsize=(14,4))
for i, miss in enumerate(miss_sam):
    x = x_test[miss] * 255  # 표준화 단계에서 255로 나누었으므로, 여기서는 곱해준다.
    ax[i].imshow(x)
    ax[i].axis('off')
    ax[i].set_title(str(y_test[miss]) + ' / ' + str(y_pred[miss]))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  lstm (LSTM)                 (None, 50)                15800
#
#  dense (Dense)               (None, 10)                510
#
# =================================================================
# Total params: 16,310
# Trainable params: 16,310
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 55/55 [==============================] - 6s 85ms/step - loss: 1.9480 - val_loss: 1.3602
# Epoch 2/50
# 55/55 [==============================] - 4s 81ms/step - loss: 0.9352 - val_loss: 0.6338
# Epoch 3/50
# 55/55 [==============================] - 4s 68ms/step - loss: 0.4969 - val_loss: 0.3921
# Epoch 4/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.3433 - val_loss: 0.3013
# Epoch 5/50
# 55/55 [==============================] - 3s 60ms/step - loss: 0.2663 - val_loss: 0.2509
# Epoch 6/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2242 - val_loss: 0.2171
# Epoch 7/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.1957 - val_loss: 0.1936
# Epoch 8/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.1754 - val_loss: 0.1772
# Epoch 9/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.1637 - val_loss: 0.1724
# Epoch 10/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.1485 - val_loss: 0.1542
# Epoch 11/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.1354 - val_loss: 0.1494
# Epoch 12/50
# 55/55 [==============================] - 4s 70ms/step - loss: 0.1273 - val_loss: 0.1347
# Epoch 13/50
# 55/55 [==============================] - 4s 70ms/step - loss: 0.1193 - val_loss: 0.1326
# Epoch 14/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.1148 - val_loss: 0.1292
# Epoch 15/50
# 55/55 [==============================] - 4s 70ms/step - loss: 0.1069 - val_loss: 0.1305
# Epoch 16/50
# 55/55 [==============================] - 4s 64ms/step - loss: 0.1018 - val_loss: 0.1141
# Epoch 17/50
# 55/55 [==============================] - 4s 77ms/step - loss: 0.0953 - val_loss: 0.1102
# Epoch 18/50
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0920 - val_loss: 0.1121
# Epoch 19/50
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0904 - val_loss: 0.1033
# Epoch 20/50
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0833 - val_loss: 0.1134
# Epoch 21/50
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0825 - val_loss: 0.1051
# Epoch 22/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0775 - val_loss: 0.0988
# Epoch 23/50
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0760 - val_loss: 0.0945
# Epoch 24/50
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0719 - val_loss: 0.0891
# Epoch 25/50
# 55/55 [==============================] - 3s 64ms/step - loss: 0.0715 - val_loss: 0.0887
# Epoch 26/50
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0684 - val_loss: 0.0856
# Epoch 27/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0648 - val_loss: 0.0872
# Epoch 28/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0639 - val_loss: 0.0844
# Epoch 29/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0641 - val_loss: 0.0818
# Epoch 30/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0621 - val_loss: 0.0832
# Epoch 31/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0604 - val_loss: 0.0909
# Epoch 32/50
# 55/55 [==============================] - 3s 64ms/step - loss: 0.0556 - val_loss: 0.0823
# Epoch 33/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0533 - val_loss: 0.0834
# Epoch 34/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0518 - val_loss: 0.0774
# Epoch 35/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0500 - val_loss: 0.0787
# Epoch 36/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0493 - val_loss: 0.0746
# Epoch 37/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0494 - val_loss: 0.0723
# Epoch 38/50
# 55/55 [==============================] - 3s 62ms/step - loss: 0.0461 - val_loss: 0.0753
# Epoch 39/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0450 - val_loss: 0.0811
# Epoch 40/50
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0477 - val_loss: 0.0734
# Epoch 41/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0435 - val_loss: 0.0798
# Epoch 42/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0449 - val_loss: 0.0729
# Epoch 43/50
# 55/55 [==============================] - 3s 62ms/step - loss: 0.0413 - val_loss: 0.0739
# Epoch 44/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0412 - val_loss: 0.0739
# Epoch 45/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0380 - val_loss: 0.0720
# Epoch 46/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0382 - val_loss: 0.0740
# Epoch 47/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0372 - val_loss: 0.0723
# Epoch 48/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0367 - val_loss: 0.0691
# Epoch 49/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0356 - val_loss: 0.0722
# Epoch 50/50
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0338 - val_loss: 0.0724
# 정확도 =0.9781
